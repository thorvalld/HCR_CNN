# %%
# Character based handwriting recognition
# CONVOLUTIONAL NEURAL NETWORK (CNN)
# github.com/thorvalld

import numpy
import pandas

import os
print(os.listdir("../input"))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
from keras.models import load_model
from sklearn.model_selection import train_test_split
import numpy

# %%
train = pandas.read_csv("../input/emnist-bymerge-train.csv")
test = pandas.read_csv("../input/emnist-bymerge-test.csv")

# %%
def load_character_mappings(mapping_path):
   mappings = {}
   with open(mapping_path) as file:
        for line in file:
            (key, value) = line.split()
            mappings[int(key)] = int(value)

   return mappings

# %%
def rotate(img):
    flipped = numpy.fliplr(img.reshape(28,28))
    return numpy.rot90(flipped).reshape(784,)
        
for i in range(len(x_test)):
    x_test[i] = rotate(x_test[i])

# %%
def rotate(img):
    flipped = numpy.fliplr(img.reshape(28,28))
    return numpy.rot90(flipped).reshape(784,)
        
for i in range(len(x_test)):
    x_train[i] = rotate(x_train[i])

# %%
number_classes = 47

# %%
y_train = train.iloc[:,0]
y_train = np_utils.to_categorical(y_train, number_classes)
print ("y_train:", y_train.shape)

# %%
x_train = train.iloc[:,1:]
x_train = x_train.astype('float32')
x_train /= 255
print ("x_train:",x_train.shape)

# %%
y_test = test.iloc[:,0]
y_test = np_utils.to_categorical(y_test, number_classes)
print ("y_test:", y_test.shape)

# %%
x_test = test.iloc[:,1:]
x_test = x_test.astype('float32')
x_test /= 255
print ("x_test:",x_test.shape)

# %%
x_train = numpy.asarray(x_train)
x_test = numpy.asarray(x_test)

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')
print(x_train.shape)
print(x_test.shape)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(number_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5, batch_size=200, verbose=2)

# %%
model.save('handwriting-recognition_model.h5')

# %%
from subprocess import check_output
print(check_output(["ls", "../working/"]).decode("utf8"))
